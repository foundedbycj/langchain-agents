# %%
from langchain.agents import create_agent
from dotenv import load_dotenv
load_dotenv()
import requests

# %%
prompt = input("enter a message:")
# Out:
# enter a message:whats the weather in dibrugarh

# %%
def weather_tool(lat,lon):
    url = f"https://api.open-meteo.com/v1/forecast?latitude={lat}&longitude={lon}&current=temperature_2m"
    response= requests.get(url)
    return response.json()

# %%
agentw = create_agent(
    model="gpt-4.5",
    tools = [weather_tool],
    system_prompt=""" you are a helpful assitant who cracks jokes and is funny
    you mostly add anime lines and just try to use anime memes etc to make
    the news fresh and refreshing , you are humorous otaku and you also
    make weather analysis. you are rated as the most humorous weather
    reporet assistant"""
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain/chat_models/base.py in _import_module(module, class_name)
#     115     try:
# --> 116         return importlib.import_module(module)
#     117     except ImportError as e:
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'langchain_openai'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
agentw.invoke(
    {'message':[{'role':'user', 'prompt':prompt}]}
)
